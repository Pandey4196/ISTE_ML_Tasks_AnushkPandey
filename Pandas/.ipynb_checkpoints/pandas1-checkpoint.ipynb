# %%
import numpy as np
import pandas as pd

# %%
myindex = ['USA','Canada','Mexico']

# %%
mydata = [1776,1867,1881]

# %%
myser = pd.Series(data=mydata,index=myindex)
myser
# Out:
# USA       1776
# Canada    1867
# Mexico    1881
# dtype: int64
